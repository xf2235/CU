# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---
# **Source:**<br>
# *Dataset adapted from: Fashion-MNIST: a Novel Image Dataset for Benchmarking Machine Learning Algorithms. Han Xiao, Kashif Rasul, Roland Vollgraf. arXiv:1708.07747*

# %% [markdown]
# # Fashion - MNIST Image Classification Competition Model Submission Guide
#
# ---
#
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data / Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade --user
# Out:
# Requirement already satisfied: aimodelshare in c:\users\administrator\appdata\roaming\python\python39\site-packages (0.0.100)
# Collecting aimodelshare
#   Using cached aimodelshare-0.0.103-py3-none-any.whl (377 kB)
# Requirement already satisfied: shortuuid>=1.0.8 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.0.9)
# Requirement already satisfied: onnx>=1.9.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.12.0)
# Requirement already satisfied: PyJWT==2.2.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (2.2.0)
# Requirement already satisfied: boto3==1.18.2 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.18.2)
# Requirement already satisfied: Pympler==0.9 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (0.9)
# Requirement already satisfied: xgboost>=0.90 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.6.1)
# Requirement already satisfied: seaborn>=0.11.2 in c:\programdata\anaconda3\lib\site-packages (from aimodelshare) (0.11.2)
# Requirement already satisfied: onnxconverter-common>=1.7.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.9.0)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.6.3)
# Requirement already satisfied: botocore==1.21.2 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.21.2)
# Requirement already satisfied: urllib3==1.25.11 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.25.11)
# Requirement already satisfied: scikit-learn==0.24.2 in c:\programdata\anaconda3\lib\site-packages (from aimodelshare) (0.24.2)
# Requirement already satisfied: tensorflow>=2.5.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (2.9.1)
# Requirement already satisfied: skl2onnx>=1.8.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.11.2)
# Requirement already satisfied: wget==3.2 in c:\programdata\anaconda3\lib\site-packages (from aimodelshare) (3.2)
# Requirement already satisfied: docker==5.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (5.0.0)
# Requirement already satisfied: tf2onnx in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.11.1)
# Requirement already satisfied: onnxruntime>=1.7.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.11.1)
# Requirement already satisfied: keras2onnx>=1.7.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.7.0)
# Requirement already satisfied: torch>=1.8.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.11.0)
# Requirement already satisfied: onnxmltools>=1.6.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.11.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from astunparse==1.6.3->aimodelshare) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse==1.6.3->aimodelshare) (0.37.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from boto3==1.18.2->aimodelshare) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from boto3==1.18.2->aimodelshare) (0.5.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\programdata\anaconda3\lib\site-packages (from botocore==1.21.2->aimodelshare) (2.8.2)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in c:\programdata\anaconda3\lib\site-packages (from docker==5.0.0->aimodelshare) (2.26.0)
# Requirement already satisfied: pywin32==227 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from docker==5.0.0->aimodelshare) (227)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from docker==5.0.0->aimodelshare) (1.3.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn==0.24.2->aimodelshare) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn==0.24.2->aimodelshare) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn==0.24.2->aimodelshare) (2.2.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn==0.24.2->aimodelshare) (1.22.4)
# Requirement already satisfied: protobuf in c:\users\administrator\appdata\roaming\python\python39\site-packages (from keras2onnx>=1.7.0->aimodelshare) (3.19.4)
# Requirement already satisfied: fire in c:\users\administrator\appdata\roaming\python\python39\site-packages (from keras2onnx>=1.7.0->aimodelshare) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in c:\programdata\anaconda3\lib\site-packages (from onnx>=1.9.0->aimodelshare) (3.10.0.2)
# Requirement already satisfied: flatbuffers in c:\users\administrator\appdata\roaming\python\python39\site-packages (from onnxruntime>=1.7.0->aimodelshare) (1.12)
# Requirement already satisfied: matplotlib>=2.2 in c:\programdata\anaconda3\lib\site-packages (from seaborn>=0.11.2->aimodelshare) (3.4.3)
# Requirement already satisfied: pandas>=0.23 in c:\programdata\anaconda3\lib\site-packages (from seaborn>=0.11.2->aimodelshare) (1.3.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (1.46.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (14.0.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=2.5.0->aimodelshare) (62.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (0.26.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=2.5.0->aimodelshare) (1.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (0.4.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (2.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=2.5.0->aimodelshare) (1.12.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=2.5.0->aimodelshare) (3.2.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (1.1.2)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (2.9.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (1.1.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=2.5.0->aimodelshare) (21.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (2.9.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (1.3.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.23->seaborn>=0.11.2->aimodelshare) (2021.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (3.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (3.3.7)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (2.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (2.0.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programdata\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (3.2.0)
# Installing collected packages: aimodelshare
#   Attempting uninstall: aimodelshare
#     Found existing installation: aimodelshare 0.0.100
#     Uninstalling aimodelshare-0.0.100:
#       Successfully uninstalled aimodelshare-0.0.100
# Successfully installed aimodelshare-0.0.103

# %%
# Get competition data
# import warnings
# warnings.simplefilter(action='ignore', category='RequestsDependencyWarning')
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/fashion_mnist_competition_data-repository:latest')

# %% [markdown]
# ##2.   Preprocess data / Write and Save Preprocessor function

# %%
# Here is a pre-designed preprocessor, but you could also build your own to prepare the data differently

def preprocessor(image_filepath, shape=(28, 28)):
        """
        This function reads in images, resizes them to a fixed shape and
        min/max transforms them before converting feature values to float32 numeric values
        required by onnx files.
        
        params:
            image_filepath
                full filepath of a particular image
                      
        returns:
            X
                numpy array of preprocessed image data
        """
           
        import cv2
        import numpy as np

        "Resize a color image and min/max transform the image"
        img = cv2.imread(image_filepath) # Read in image from filepath.
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) # cv2 reads in images in order of blue green and red, we reverse the order for ML.
        img = cv2.resize(img, shape) # Change height and width of image.
        img = img / 255.0 # Min-max transform.

        # Resize all the images...
        X = np.array(img)
        X = np.expand_dims(X, axis=0) # Expand dims to add "1" to object shape [1, h, w, channels] for keras model.
        X = np.array(X, dtype=np.float32) # Final shape for onnx runtime.
        return X

# %%
#  Create training data objects

# Preprocess X_train image data to generate predictions from models 
import numpy as np

file_names = [('fashion_mnist_competition_data/training_data/train_' + str(i) + '.jpeg') for i in range(60000)]
preprocessed_image_data = [preprocessor(x) for x in file_names]

#Create single X_test array from preprocessed images
X_train = np.vstack(preprocessed_image_data) 

# Load y_train labels 
import pickle
with open("fashion_mnist_competition_data/y_train_labels.pkl", "rb") as fp:  
    y_train_labels = pickle.load(fp)

# One-hot encode y_train labels (y_train.columns used to generate prediction labels below)
import pandas as pd
y_train = pd.get_dummies(y_train_labels)

# %%
# Create test data objects

# Preprocess X_test image data to generate predictions from models 
import numpy as np

file_names = [('fashion_mnist_competition_data/test_data/test_' + str(i) + '.jpeg') for i in range(10000)]
preprocessed_image_data = [preprocessor(x) for x in file_names]

#Create single X_test array from preprocessed images
X_test = np.vstack(preprocessed_image_data)

# %%
# Check shape 

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
# Out:
# (60000, 28, 28, 3)
# (10000, 28, 28, 3)
# (60000, 10)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
# Let's build a convnet model...
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import SGD

with tf.device('/device:GPU:0'): # "/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.
                                 
        cnn1 = Sequential()
        cnn1.add(Conv2D(filters=16, kernel_size=4, padding='same', activation='relu', input_shape=[28, 28, 3]))
        cnn1.add(Conv2D(filters=16, kernel_size=4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
        cnn1.add(MaxPooling2D(pool_size=2)) 
        cnn1.add(Conv2D(filters=32, kernel_size=4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
        cnn1.add(Conv2D(filters=32, kernel_size=4, padding='same', activation='relu'))
        cnn1.add(MaxPooling2D(pool_size=2))
        cnn1.add(Conv2D(filters=64, kernel_size=4, padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
        cnn1.add(Conv2D(filters=64, kernel_size=4, padding='same', activation='relu'))
        cnn1.add(MaxPooling2D(pool_size=2))
        cnn1.add(Dropout(0.3))
        cnn1.add(Flatten())
        cnn1.add(Dense(500, activation='relu'))
        cnn1.add(Dense(500, activation='relu'))
        cnn1.add(Dense(500, activation='relu'))
        cnn1.add(Dropout(0.2))
        cnn1.add(Dense(10, activation='softmax'))

        # Compile model...
        cnn1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
        
        
        # Fitting the NN to the Training set...
        hist = cnn1.fit(X_train, y_train, epochs=1, verbose=1, validation_split=0.2)
# Out:
# 1500/1500 [==============================] - 164s 109ms/step - loss: 0.6995 - accuracy: 0.7786 - val_loss: 0.4969 - val_accuracy: 0.8371

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(cnn1, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
    
apiurl="https://vaw5a558u9.execute-api.us-east-1.amazonaws.com/prod/m" #This is the unique rest api that powers this Fashion-MNIST Classification Model Playground

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username: ············
# AI Modelshare Password: ···············
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition

mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted y values (Model 1)
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=cnn1.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 313/313 [==============================] - 8s 26ms/step
# 100% [................................................................................] 6878 / 6878
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
# Your model has been submitted as model version 54
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1662

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_a0ca8_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 93.1%, transparent 93.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a0ca8_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 93.1%, transparent 93.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a0ca8_row0_col2, #T_a0ca8_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 93.1%, transparent 93.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a0ca8_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 93.1%, transparent 93.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_a0ca8_row0_col4, #T_a0ca8_row0_col5, #T_a0ca8_row0_col6, #T_a0ca8_row0_col7, #T_a0ca8_row0_col8, #T_a0ca8_row0_col9, #T_a0ca8_row0_col10, #T_a0ca8_row0_col11, #T_a0ca8_row0_col12, #T_a0ca8_row0_col13, #T_a0ca8_row0_col14, #T_a0ca8_row0_col15, #T_a0ca8_row0_col16, #T_a0ca8_row0_col17, #T_a0ca8_row0_col18, #T_a0ca8_row0_col19, #T_a0ca8_row0_col20, #T_a0ca8_row0_col21, #T_a0ca8_row1_col4, #T_a0ca8_row1_col5, #T_a0ca8_row1_col6, #T_a0ca8_row1_col7, #T_a0ca8_row1_col8, #T_a0ca8_row1_col9, #T_a0ca8_row1_col10, #T_a0ca8_row1_col11, #T_a0ca8_row1_col12, #T_a0ca8_row1_col13, #T_a0ca8_row1_col14, #T_a0ca8_row1_col15, #T_a0ca8_row1_col16, #T_a0ca8_row1_col17, #T_a0ca8_row1_col18, #T_a0ca8_row1_col19, #T_a0ca8_row1_col20, #T_a0ca8_row1_col21, #T_a0ca8_row2_col4, #T_a0ca8_row2_col5, #T_a0ca8_row2_col6, #T_a0ca8_row2_col7, #T_a0ca8_row2_col8, #T_a0ca8_row2_col9, #T_a0ca8_row2_col10, #T_a0ca8_row2_col11, #T_a0ca8_row2_col12, #T_a0ca8_row2_col13, #T_a0ca8_row2_col14, #T_a0ca8_row2_col15, #T_a0ca8_row2_col16, #T_a0ca8_row2_col17, #T_a0ca8_row2_col18, #T_a0ca8_row2_col19, #T_a0ca8_row2_col20, #T_a0ca8_row2_col21, #T_a0ca8_row3_col4, #T_a0ca8_row3_col5, #T_a0ca8_row3_col6, #T_a0ca8_row3_col7, #T_a0ca8_row3_col8, #T_a0ca8_row3_col9, #T_a0ca8_row3_col10, #T_a0ca8_row3_col11, #T_a0ca8_row3_col12, #T_a0ca8_row3_col13, #T_a0ca8_row3_col14, #T_a0ca8_row3_col15, #T_a0ca8_row3_col16, #T_a0ca8_row3_col17, #T_a0ca8_row3_col18, #T_a0ca8_row3_col19, #T_a0ca8_row3_col20, #T_a0ca8_row3_col21, #T_a0ca8_row4_col4, #T_a0ca8_row4_col5, #T_a0ca8_row4_col6, #T_a0ca8_row4_col7, #T_a0ca8_row4_col8, #T_a0ca8_row4_col9, #T_a0ca8_row4_col10, #T_a0ca8_row4_col11, #T_a0ca8_row4_col12, #T_a0ca8_row4_col13, #T_a0ca8_row4_col14, #T_a0ca8_row4_col15, #T_a0ca8_row4_col16, #T_a0ca8_row4_col17, #T_a0ca8_row4_col18, #T_a0ca8_row4_col19, #T_a0ca8_row4_col20, #T_a0ca8_row4_col21, #T_a0ca8_row5_col4, #T_a0ca8_row5_col5, #T_a0ca8_row5_col6, #T_a0ca8_row5_col7, #T_a0ca8_row5_col8, #T_a0ca8_row5_col9, #T_a0ca8_row5_col10, #T_a0ca8_row5_col11, #T_a0ca8_row5_col12, #T_a0ca8_row5_col13, #T_a0ca8_row5_col14, #T_a0ca8_row5_col15, #T_a0ca8_row5_col16, #T_a0ca8_row5_col17, #T_a0ca8_row5_col18, #T_a0ca8_row5_col19, #T_a0ca8_row5_col20, #T_a0ca8_row5_col21, #T_a0ca8_row6_col4, #T_a0ca8_row6_col5, #T_a0ca8_row6_col6, #T_a0ca8_row6_col7, #T_a0ca8_row6_col8, #T_a0ca8_row6_col9, #T_a0ca8_row6_col10, #T_a0ca8_row6_col11, #T_a0ca8_row6_col12, #T_a0ca8_row6_col13, #T_a0ca8_row6_col14, #T_a0ca8_row6_col15, #T_a0ca8_row6_col16, #T_a0ca8_row6_col17, #T_a0ca8_row6_col18, #T_a0ca8_row6_col19, #T_a0ca8_row6_col20, #T_a0ca8_row6_col21, #T_a0ca8_row7_col4, #T_a0ca8_row7_col5, #T_a0ca8_row7_col6, #T_a0ca8_row7_col7, #T_a0ca8_row7_col8, #T_a0ca8_row7_col9, #T_a0ca8_row7_col10, #T_a0ca8_row7_col11, #T_a0ca8_row7_col12, #T_a0ca8_row7_col13, #T_a0ca8_row7_col14, #T_a0ca8_row7_col15, #T_a0ca8_row7_col16, #T_a0ca8_row7_col17, #T_a0ca8_row7_col18, #T_a0ca8_row7_col19, #T_a0ca8_row7_col20, #T_a0ca8_row7_col21, #T_a0ca8_row8_col4, #T_a0ca8_row8_col5, #T_a0ca8_row8_col6, #T_a0ca8_row8_col7, #T_a0ca8_row8_col8, #T_a0ca8_row8_col9, #T_a0ca8_row8_col10, #T_a0ca8_row8_col11, #T_a0ca8_row8_col12, #T_a0ca8_row8_col13, #T_a0ca8_row8_col14, #T_a0ca8_row8_col15, #T_a0ca8_row8_col16, #T_a0ca8_row8_col17, #T_a0ca8_row8_col18, #T_a0ca8_row8_col19, #T_a0ca8_row8_col20, #T_a0ca8_row8_col21, #T_a0ca8_row9_col4, #T_a0ca8_row9_col5, #T_a0ca8_row9_col6, #T_a0ca8_row9_col7, #T_a0ca8_row9_col8, #T_a0ca8_row9_col9, #T_a0ca8_row9_col10, #T_a0ca8_row9_col11, #T_a0ca8_row9_col12, #T_a0ca8_row9_col13, #T_a0ca8_row9_col14, #T_a0ca8_row9_col15, #T_a0ca8_row9_col16, #T_a0ca8_row9_col17, #T_a0ca8_row9_col18, #T_a0ca8_row9_col19, #T_a0ca8_row9_col20, #T_a0ca8_row9_col21, #T_a0ca8_row10_col4, #T_a0ca8_row10_col5, #T_a0ca8_row10_col6, #T_a0ca8_row10_col7, #T_a0ca8_row10_col8, #T_a0ca8_row10_col9, #T_a0ca8_row10_col10, #T_a0ca8_row10_col11, #T_a0ca8_row10_col12, #T_a0ca8_row10_col13, #T_a0ca8_row10_col14, #T_a0ca8_row10_col15, #T_a0ca8_row10_col16,  ...

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).

with tf.device('/device:GPU:0'): # "/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.
      densemodel = Sequential()
      densemodel.add(Dense(128,  input_shape=(28, 28, 3), activation='relu'))
      densemodel.add(Dense(64, activation='relu'))
      densemodel.add(Dense(64, activation='relu'))
      densemodel.add(Flatten())
      densemodel.add(Dense(10, activation='softmax')) 
                                                  
      # Compile model
      densemodel.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

      # Fitting the NN to the Training set
      densemodel.fit(X_train, y_train, 
                    epochs = 1, verbose=1, validation_split=.2)
# Out:
# 1500/1500 [==============================] - 61s 40ms/step - loss: 0.4996 - accuracy: 0.8209 - val_loss: 0.4133 - val_accuracy: 0.8522

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(densemodel, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_column_index=densemodel.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 313/313 [==============================] - 4s 12ms/step
# 100% [................................................................................] 6878 / 6878
# Insert search tags to help users find your model (optional):  2
# Provide any useful notes about your model (optional):
# Your model has been submitted as model version 29
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1662

# %%
# Compare two or more models 
data=mycompetition.compare_models([3,4], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_f6434_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_f6434_row0_col0, #T_f6434_row1_col0, #T_f6434_row3_col0, #T_f6434_row4_col0 {
#   background: #fdcdac;
#   color: black;
#   color: black;
# }
# #T_f6434_row0_col1, #T_f6434_row0_col2, #T_f6434_row0_col4, #T_f6434_row0_col5, #T_f6434_row1_col1, #T_f6434_row1_col2, #T_f6434_row1_col4, #T_f6434_row1_col5, #T_f6434_row2_col1, #T_f6434_row2_col2, #T_f6434_row2_col4, #T_f6434_row2_col5, #T_f6434_row3_col1, #T_f6434_row3_col2, #T_f6434_row3_col4, #T_f6434_row3_col5, #T_f6434_row4_col1, #T_f6434_row4_col2, #T_f6434_row4_col4, #T_f6434_row4_col5, #T_f6434_row5_col1, #T_f6434_row5_col2, #T_f6434_row5_col3, #T_f6434_row5_col4, #T_f6434_row5_col5, #T_f6434_row6_col1, #T_f6434_row6_col2, #T_f6434_row6_col3, #T_f6434_row6_col4, #T_f6434_row6_col5, #T_f6434_row7_col1, #T_f6434_row7_col2, #T_f6434_row7_col3, #T_f6434_row7_col4, #T_f6434_row7_col5, #T_f6434_row8_col1, #T_f6434_row8_col2, #T_f6434_row8_col3, #T_f6434_row8_col4, #T_f6434_row8_col5, #T_f6434_row9_col1, #T_f6434_row9_col2, #T_f6434_row9_col3, #T_f6434_row9_col4, #T_f6434_row9_col5, #T_f6434_row10_col1, #T_f6434_row10_col2, #T_f6434_row10_col3, #T_f6434_row10_col4, #T_f6434_row10_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_f6434_row0_col3, #T_f6434_row1_col3, #T_f6434_row2_col3, #T_f6434_row4_col3, #T_f6434_row8_col0, #T_f6434_row10_col0 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_f6434_row2_col0, #T_f6434_row5_col0 {
#   background: #f1e2cc;
#   color: black;
#   color: black;
# }
# #T_f6434_row3_col3, #T_f6434_row7_col0 {
#   background: #e6f5c9;
#   color: black;
#   color: black;
# }
# #T_f6434_row6_col0, #T_f6434_row9_col0 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_f6434_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_3_Layer</th>
#       <th class="col_heading level0 col1" >Model_3_Shape</th>
#       <th class="col_heading level0 col2" >Model_3_Params</th>
#       <th class="col_heading level0 col3" >Model_4_Layer</th>
#       <th class="col_heading level0 col4" >Model_4_Shape</th>
#       <th class="col_heading level0 col5" >Model_4_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6434_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6434_row0_col0" class="data row0 col0" >Conv2D</td>
#       <td id="T_f6434_row0_col1" class="data row0 col1" >[None, 28, 28, 16]</td>
#       <td id="T_f6434_row0_col2" class="data row0 col2" >448</td>
#       <td id="T_f6434_row0_col3" class="data row0 col3" >Dense</td>
#       <td id="T_f6434_row0_col4" class="data row0 col4" >[None, 28, 28, 128]</td>
#       <td id="T_f6434_row0_col5" class="data row0 col5" >512.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6434_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6434_row1_col0" class="data row1 col0" >Conv2D</td>
#       <td id="T_f6434_row1_col1" class="data row1 col1" >[None, 28, 28, 16]</td>
#       <td id="T_f6434_row1_col2" class="data row1 col2" >2320</td>
#       <td id="T_f6434_row1_col3" class="data row1 col3" >Dense</td>
#       <td id="T_f6434_row1_col4" class="data row1 col4" >[None, 28, 28, 64]</td>
#       <td id="T_f6434_row1_col5" class="data row1 col5" >8256.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6434_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f6434_row2_col0" class="data row2 col0" >MaxPooling2D</td>
#       <td id="T_f6434_row2_col1" class="data row2 col1" >[None, 14, 14, 16]</td>
#       <td id="T_f6434_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_f6434_row2_col3" class="data row2 col3" >Dense</td>
#       <td id="T_f6434_row2_col4" class="data row2 col4" >[None, 28, 28, 64]</td>
#       <td id="T_f6434_row2_col5" class="data row2 col5" >4160.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6434_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f6434_row3_col0" class="data row3 col0" >Conv2D</td>
#       <td id="T_f6434_row3_col1" class="data row3 col1" >[None, 14, 14, 16]</td>
#       <td id="T_f6434_row3_col2" class="data row3 col2" >2320</td>
#       <td id="T_f6434_row3_col3" class="data row3 col3" >Flatten</td>
#       <td id="T_f6434_row3_col4" class="data row3 col4" >[None, 50176]</td>
#       <td id="T_f6434_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6434_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f6434_row4_col0" class="data row4 col0" >Conv2D</td>
#       <td id="T_f6434_row4_col1" class="data row4 col1" >[None, 14, 14, 16]</td>
#       <td id="T_f6434_row4_col2" class="data row4 col2" >2320</td>
#       <td id="T_f6434_row4_col3" class="data row4 col3" >Dense</td>
#       <td id="T_f6434_row4_col4" class="data row4 col4" >[None, 10]</td>
#       <td id="T_f6434_row4_col5" class="data row4 col5" >501770.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f6434_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f6434_row5_col0" class="data row5 col0" >MaxPooling2D</td>
#       <td id="T_f6434_row5_col1" class="data row5 col1" >[None, 7, 7, 16]</td>
#       <td id="T_f6434_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_f6434_row5_col3" class="data row5 col3" >None</td>
#       <td id="T_f6434_row5_col4" class="data row5 col4" >None</td>
#       <td id="T_f6434_row5_col5" class="data row5 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f6434_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f6434_row6_col0" class="data row6 col0" >Dropout</td>
#       <td id="T_f6434_row6_col1" class="data row6 col1" >[None, 7, 7, 16]</td>
#       <td id="T_f6434_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_f6434_row6_col3" class="data row6 col3" >None</td>
#       <td id="T_f6434_row6_col4" class="data row6 col4" >None</td>
#       <td id="T_f6434_row6_col5" class="data row6 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f6434_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f6434_row7_col0" class="data row7 col0" >Flatten</td>
#       <td id="T_f6434_row7_col1" class="data row7 col1" >[None, 784]</td>
#       <td id="T_f6434_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_f6434_row7_col3" class="data row7 col3" >None</td>
#       <td id="T_f6434_row7_col4" class="data row7 col4" >None</td>
#       <td id="T_f6434_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f6434_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f6434_row8_col0" class="data row8 col0" >Dense</td>
#       <td id="T_f6434_row8_col1" class="data row8 col1" >[None, 50]</td>
#       <td id="T_f6434_row8_col2" class="data row8 col2" >39250</td>
#       <td id="T_f6434_row8_col3" class="data row8 col3" >None</td>
#       <td id="T_f6434_row8_col4" class="data row8 col4" >None</td>
#       <td id="T_f6434_row8_col5" class="data row8 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f6434_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f6434_row9_col0" class="data row9 col0" >Dropout</td>
#       <td id="T_f6434_row9_col1" class="data row9 col1" >[None, 50]</td>
#       <td id="T_f6434_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_f6434_row9_col3" class="data row9 col3" >None</td>
#       <td id="T_f6434_row9_col4" class="data row9 col4" >None</td>
#       <td id="T_f6434_row9_col5" class="data row9 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f6434_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f6434_row10_col0" class="data row10 col0" >Dense</td>
#       <td id="T_f6434_row10_col1" class="data row10 col1" >[None, 10]</td>
#       <td id="T_f6434_row10_col2" class="data row10 col2" >510</td>
#       <td id="T_f6434_row10_col3" class="data row10 col3" >None</td>
#       <td id="T_f6434_row10_col4" class="data row10 col4" >None</td>
#       <td id="T_f6434_row10_col5" class="data row10 col5" >nan</td>
#     </tr>

# %% [markdown]
# ## Optional: Tune model within range of hyperparameters with Keras Tuner
#
# *Simple example shown below. Consult [documentation](https://keras.io/guides/keras_tuner/getting_started/) to see full functionality.*

# %%
! pip install keras_tuner
# Out:
# Collecting keras_tuner
#   Downloading keras_tuner-1.1.2-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.7/133.7 kB 4.0 MB/s eta 0:00:00
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from keras_tuner) (2.26.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from keras_tuner) (1.22.4)
# Requirement already satisfied: ipython in c:\programdata\anaconda3\lib\site-packages (from keras_tuner) (7.29.0)
# Requirement already satisfied: tensorboard in c:\users\administrator\appdata\roaming\python\python39\site-packages (from keras_tuner) (2.9.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from keras_tuner) (21.0)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython->keras_tuner) (62.1.0)
# Requirement already satisfied: traitlets>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipython->keras_tuner) (5.1.0)
# Requirement already satisfied: matplotlib-inline in c:\programdata\anaconda3\lib\site-packages (from ipython->keras_tuner) (0.1.2)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython->keras_tuner) (0.7.5)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython->keras_tuner) (0.2.0)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython->keras_tuner) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython->keras_tuner) (0.18.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython->keras_tuner) (0.4.4)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython->keras_tuner) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython->keras_tuner) (3.0.20)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging->keras_tuner) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->keras_tuner) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->keras_tuner) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from requests->keras_tuner) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->keras_tuner) (2021.10.8)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard->keras_tuner) (2.8.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard->keras_tuner) (1.46.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard->keras_tuner) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard->keras_tuner) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard->keras_tuner) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras_tuner) (2.0.2)
# Requirement already satisfied: absl-py>=0.4 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard->keras_tuner) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras_tuner) (0.37.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard->keras_tuner) (3.19.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard->keras_tuner) (1.8.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (4.8)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython->keras_tuner) (0.8.2)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programdata\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard->keras_tuner) (4.8.1)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->keras_tuner) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras_tuner) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras_tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras_tuner) (3.2.0)
# Installing collected packages: kt-legacy, keras_tuner
# Successfully installed keras_tuner-1.1.2 kt-legacy-1.0.4

# %%
#Separate validation data 
from sklearn.model_selection import train_test_split
x_train_split, x_val, y_train_split, y_val = train_test_split(
     X_train, y_train, test_size=0.2, random_state=42)

# %%
import keras_tuner as kt
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras import regularizers

#Define model structure & parameter search space with function
def build_model(hp):
    with tf.device('/device:GPU:0'): # "/GPU:0": Short-hand notation for the first GPU of your machine that is visible to TensorFlow.
                                 
        model = Sequential()
        model.add(Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=[28, 28, 3]))
        model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
        model.add(MaxPooling2D(pool_size=2)) 
        model.add(Conv2D(filters=64, kernel_size=3, padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
        model.add(Conv2D(filters=hp.Int("filters", min_value=8, max_value=128, step=8), #range 8-32 inclusive, minimum step between tested values is 8
                         kernel_size=3, padding='same', activation='relu'))
        model.add(MaxPooling2D(pool_size=2))
        model.add(Dropout(0.3))
        model.add(Flatten())
        model.add(Dense(50, activation='relu'))
        model.add(Dropout(0.2))
        model.add(Dense(10, activation='softmax'))

        # Compile model...
        model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

        return model 

#initialize the tuner (which will search through parameters)
tuner = kt.RandomSearch(
    hypermodel=build_model, 
    objective="val_accuracy", # objective to optimize
    max_trials=2, #max number of trials to run during search
    executions_per_trial=1, #higher number reduces variance of results; guages model performance more accurately 
    overwrite=True,
    directory="tuning_model",
    project_name="tuning_units",
)

tuner.search(x_train_split, y_train_split, epochs=1, validation_data=(x_val, y_val))

# %%
# Build model with best hyperparameters

# Get the top 2 hyperparameters.
best_hps = tuner.get_best_hyperparameters(5)
# Build the model with the best hp.
tuned_model = build_model(best_hps[0])
# Fit with the entire dataset.
tuned_model.fit(x=X_train, y=y_train, epochs=10)
# Out:
# 1875/1875 [==============================] - 51s 27ms/step - loss: 0.6366 - accuracy: 0.7948

# %%
# Save keras model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(tuned_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("tuned_model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted y values (Model 3)
prediction_column_index=tuned_model.predict(X_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 3 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "tuned_model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 313/313 [==============================] - 2s 7ms/step
# 100% [................................................................................] 6878 / 6878
# Insert search tags to help users find your model (optional):  3
# Provide any useful notes about your model (optional):
# Your model has been submitted as model version 30
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1662

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_84800_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 92.4%, transparent 92.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_84800_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 92.3%, transparent 92.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_84800_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 92.3%, transparent 92.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_84800_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 92.4%, transparent 92.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_84800_row0_col4, #T_84800_row0_col5, #T_84800_row0_col6, #T_84800_row0_col7, #T_84800_row0_col8, #T_84800_row0_col9, #T_84800_row0_col10, #T_84800_row0_col11, #T_84800_row0_col12, #T_84800_row0_col13, #T_84800_row0_col14, #T_84800_row0_col15, #T_84800_row0_col16, #T_84800_row0_col17, #T_84800_row0_col18, #T_84800_row0_col19, #T_84800_row0_col20, #T_84800_row0_col21, #T_84800_row1_col4, #T_84800_row1_col5, #T_84800_row1_col6, #T_84800_row1_col7, #T_84800_row1_col8, #T_84800_row1_col9, #T_84800_row1_col10, #T_84800_row1_col11, #T_84800_row1_col12, #T_84800_row1_col13, #T_84800_row1_col14, #T_84800_row1_col15, #T_84800_row1_col16, #T_84800_row1_col17, #T_84800_row1_col18, #T_84800_row1_col19, #T_84800_row1_col20, #T_84800_row1_col21, #T_84800_row2_col4, #T_84800_row2_col5, #T_84800_row2_col6, #T_84800_row2_col7, #T_84800_row2_col8, #T_84800_row2_col9, #T_84800_row2_col10, #T_84800_row2_col11, #T_84800_row2_col12, #T_84800_row2_col13, #T_84800_row2_col14, #T_84800_row2_col15, #T_84800_row2_col16, #T_84800_row2_col17, #T_84800_row2_col18, #T_84800_row2_col19, #T_84800_row2_col20, #T_84800_row2_col21, #T_84800_row3_col4, #T_84800_row3_col5, #T_84800_row3_col6, #T_84800_row3_col7, #T_84800_row3_col8, #T_84800_row3_col9, #T_84800_row3_col10, #T_84800_row3_col11, #T_84800_row3_col12, #T_84800_row3_col13, #T_84800_row3_col14, #T_84800_row3_col15, #T_84800_row3_col16, #T_84800_row3_col17, #T_84800_row3_col18, #T_84800_row3_col19, #T_84800_row3_col20, #T_84800_row3_col21, #T_84800_row4_col4, #T_84800_row4_col5, #T_84800_row4_col6, #T_84800_row4_col7, #T_84800_row4_col8, #T_84800_row4_col9, #T_84800_row4_col10, #T_84800_row4_col11, #T_84800_row4_col12, #T_84800_row4_col13, #T_84800_row4_col14, #T_84800_row4_col15, #T_84800_row4_col16, #T_84800_row4_col17, #T_84800_row4_col18, #T_84800_row4_col19, #T_84800_row4_col20, #T_84800_row4_col21, #T_84800_row5_col4, #T_84800_row5_col5, #T_84800_row5_col6, #T_84800_row5_col7, #T_84800_row5_col8, #T_84800_row5_col9, #T_84800_row5_col10, #T_84800_row5_col11, #T_84800_row5_col12, #T_84800_row5_col13, #T_84800_row5_col14, #T_84800_row5_col15, #T_84800_row5_col16, #T_84800_row5_col17, #T_84800_row5_col18, #T_84800_row5_col19, #T_84800_row5_col20, #T_84800_row5_col21, #T_84800_row6_col4, #T_84800_row6_col5, #T_84800_row6_col6, #T_84800_row6_col7, #T_84800_row6_col8, #T_84800_row6_col9, #T_84800_row6_col10, #T_84800_row6_col11, #T_84800_row6_col12, #T_84800_row6_col13, #T_84800_row6_col14, #T_84800_row6_col15, #T_84800_row6_col16, #T_84800_row6_col17, #T_84800_row6_col18, #T_84800_row6_col19, #T_84800_row6_col20, #T_84800_row6_col21, #T_84800_row7_col4, #T_84800_row7_col5, #T_84800_row7_col6, #T_84800_row7_col7, #T_84800_row7_col8, #T_84800_row7_col9, #T_84800_row7_col10, #T_84800_row7_col11, #T_84800_row7_col12, #T_84800_row7_col13, #T_84800_row7_col14, #T_84800_row7_col15, #T_84800_row7_col16, #T_84800_row7_col17, #T_84800_row7_col18, #T_84800_row7_col19, #T_84800_row7_col20, #T_84800_row7_col21, #T_84800_row8_col4, #T_84800_row8_col5, #T_84800_row8_col6, #T_84800_row8_col7, #T_84800_row8_col8, #T_84800_row8_col9, #T_84800_row8_col10, #T_84800_row8_col11, #T_84800_row8_col12, #T_84800_row8_col13, #T_84800_row8_col14, #T_84800_row8_col15, #T_84800_row8_col16, #T_84800_row8_col17, #T_84800_row8_col18, #T_84800_row8_col19, #T_84800_row8_col20, #T_84800_row8_col21, #T_84800_row9_col4, #T_84800_row9_col5, #T_84800_row9_col6, #T_84800_row9_col7, #T_84800_row9_col8, #T_84800_row9_col9, #T_84800_row9_col10, #T_84800_row9_col11, #T_84800_row9_col12, #T_84800_row9_col13, #T_84800_row9_col14, #T_84800_row9_col15, #T_84800_row9_col16, #T_84800_row9_col17, #T_84800_row9_col18, #T_84800_row9_col19, #T_84800_row9_col20, #T_84800_row9_col21, #T_84800_row10_col4, #T_84800_row10_col5, #T_84800_row10_col6, #T_84800_row10_col7, #T_84800_row10_col8, #T_84800_row10_col9, #T_84800_row10_col10, #T_84800_row10_col11, #T_84800_row10_col12, #T_84800_row10_col13, #T_84800_row10_col14, #T_84800_row10_col15, #T_84800_row10_col16,  ...

# %%
# Compare two or more models 
data=mycompetition.compare_models([4, 5], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_459c5_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_459c5_row0_col0, #T_459c5_row1_col0, #T_459c5_row2_col0, #T_459c5_row4_col0, #T_459c5_row8_col3, #T_459c5_row10_col3 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_459c5_row0_col1, #T_459c5_row0_col2, #T_459c5_row0_col4, #T_459c5_row0_col5, #T_459c5_row1_col1, #T_459c5_row1_col2, #T_459c5_row1_col4, #T_459c5_row1_col5, #T_459c5_row2_col1, #T_459c5_row2_col2, #T_459c5_row2_col4, #T_459c5_row2_col5, #T_459c5_row3_col1, #T_459c5_row3_col2, #T_459c5_row3_col4, #T_459c5_row3_col5, #T_459c5_row4_col1, #T_459c5_row4_col2, #T_459c5_row4_col4, #T_459c5_row4_col5, #T_459c5_row5_col0, #T_459c5_row5_col1, #T_459c5_row5_col2, #T_459c5_row5_col4, #T_459c5_row5_col5, #T_459c5_row6_col0, #T_459c5_row6_col1, #T_459c5_row6_col2, #T_459c5_row6_col4, #T_459c5_row6_col5, #T_459c5_row7_col0, #T_459c5_row7_col1, #T_459c5_row7_col2, #T_459c5_row7_col4, #T_459c5_row7_col5, #T_459c5_row8_col0, #T_459c5_row8_col1, #T_459c5_row8_col2, #T_459c5_row8_col4, #T_459c5_row8_col5, #T_459c5_row9_col0, #T_459c5_row9_col1, #T_459c5_row9_col2, #T_459c5_row9_col4, #T_459c5_row9_col5, #T_459c5_row10_col0, #T_459c5_row10_col1, #T_459c5_row10_col2, #T_459c5_row10_col4, #T_459c5_row10_col5 {
#   background: white;
#   color: black;
#   color: black;
# }
# #T_459c5_row0_col3, #T_459c5_row1_col3, #T_459c5_row3_col3, #T_459c5_row4_col3 {
#   background: #fdcdac;
#   color: black;
#   color: black;
# }
# #T_459c5_row2_col3, #T_459c5_row5_col3 {
#   background: #f1e2cc;
#   color: black;
#   color: black;
# }
# #T_459c5_row3_col0, #T_459c5_row7_col3 {
#   background: #e6f5c9;
#   color: black;
#   color: black;
# }
# #T_459c5_row6_col3, #T_459c5_row9_col3 {
#   background: #cbd5e8;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_459c5_">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model_4_Layer</th>
#       <th class="col_heading level0 col1" >Model_4_Shape</th>
#       <th class="col_heading level0 col2" >Model_4_Params</th>
#       <th class="col_heading level0 col3" >Model_5_Layer</th>
#       <th class="col_heading level0 col4" >Model_5_Shape</th>
#       <th class="col_heading level0 col5" >Model_5_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_459c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_459c5_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_459c5_row0_col1" class="data row0 col1" >[None, 28, 28, 128]</td>
#       <td id="T_459c5_row0_col2" class="data row0 col2" >512.000000</td>
#       <td id="T_459c5_row0_col3" class="data row0 col3" >Conv2D</td>
#       <td id="T_459c5_row0_col4" class="data row0 col4" >[None, 28, 28, 16]</td>
#       <td id="T_459c5_row0_col5" class="data row0 col5" >448</td>
#     </tr>
#     <tr>
#       <th id="T_459c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_459c5_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_459c5_row1_col1" class="data row1 col1" >[None, 28, 28, 64]</td>
#       <td id="T_459c5_row1_col2" class="data row1 col2" >8256.000000</td>
#       <td id="T_459c5_row1_col3" class="data row1 col3" >Conv2D</td>
#       <td id="T_459c5_row1_col4" class="data row1 col4" >[None, 28, 28, 16]</td>
#       <td id="T_459c5_row1_col5" class="data row1 col5" >2320</td>
#     </tr>
#     <tr>
#       <th id="T_459c5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_459c5_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_459c5_row2_col1" class="data row2 col1" >[None, 28, 28, 64]</td>
#       <td id="T_459c5_row2_col2" class="data row2 col2" >4160.000000</td>
#       <td id="T_459c5_row2_col3" class="data row2 col3" >MaxPooling2D</td>
#       <td id="T_459c5_row2_col4" class="data row2 col4" >[None, 14, 14, 16]</td>
#       <td id="T_459c5_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_459c5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_459c5_row3_col0" class="data row3 col0" >Flatten</td>
#       <td id="T_459c5_row3_col1" class="data row3 col1" >[None, 50176]</td>
#       <td id="T_459c5_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_459c5_row3_col3" class="data row3 col3" >Conv2D</td>
#       <td id="T_459c5_row3_col4" class="data row3 col4" >[None, 14, 14, 16]</td>
#       <td id="T_459c5_row3_col5" class="data row3 col5" >2320</td>
#     </tr>
#     <tr>
#       <th id="T_459c5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_459c5_row4_col0" class="data row4 col0" >Dense</td>
#       <td id="T_459c5_row4_col1" class="data row4 col1" >[None, 10]</td>
#       <td id="T_459c5_row4_col2" class="data row4 col2" >501770.000000</td>
#       <td id="T_459c5_row4_col3" class="data row4 col3" >Conv2D</td>
#       <td id="T_459c5_row4_col4" class="data row4 col4" >[None, 14, 14, 16]</td>
#       <td id="T_459c5_row4_col5" class="data row4 col5" >2320</td>
#     </tr>
#     <tr>
#       <th id="T_459c5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_459c5_row5_col0" class="data row5 col0" >None</td>
#       <td id="T_459c5_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_459c5_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_459c5_row5_col3" class="data row5 col3" >MaxPooling2D</td>
#       <td id="T_459c5_row5_col4" class="data row5 col4" >[None, 7, 7, 16]</td>
#       <td id="T_459c5_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_459c5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_459c5_row6_col0" class="data row6 col0" >None</td>
#       <td id="T_459c5_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_459c5_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_459c5_row6_col3" class="data row6 col3" >Dropout</td>
#       <td id="T_459c5_row6_col4" class="data row6 col4" >[None, 7, 7, 16]</td>
#       <td id="T_459c5_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_459c5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_459c5_row7_col0" class="data row7 col0" >None</td>
#       <td id="T_459c5_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_459c5_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_459c5_row7_col3" class="data row7 col3" >Flatten</td>
#       <td id="T_459c5_row7_col4" class="data row7 col4" >[None, 784]</td>
#       <td id="T_459c5_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_459c5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_459c5_row8_col0" class="data row8 col0" >None</td>
#       <td id="T_459c5_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_459c5_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_459c5_row8_col3" class="data row8 col3" >Dense</td>
#       <td id="T_459c5_row8_col4" class="data row8 col4" >[None, 50]</td>
#       <td id="T_459c5_row8_col5" class="data row8 col5" >39250</td>
#     </tr>
#     <tr>
#       <th id="T_459c5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_459c5_row9_col0" class="data row9 col0" >None</td>
#       <td id="T_459c5_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_459c5_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_459c5_row9_col3" class="data row9 col3" >Dropout</td>
#       <td id="T_459c5_row9_col4" class="data row9 col4" >[None, 50]</td>
#       <td id="T_459c5_row9_col5" class="data row9 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_459c5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_459c5_row10_col0" class="data row10 col0" >None</td>
#       <td id="T_459c5_row10_col1" class="data row10 col1" >None</td>
#       <td id="T_459c5_row10_col2" class="data row10 col2" >nan</td>
#       <td id="T_459c5_row10_col3" class="data row10 col3" >Dense</td>
#       <td id="T_459c5_row10_col4" class="data row10 col4" >[None, 10]</td>
#       <td id="T_459c5_row10_col5" class="data row10 col5" >510</td>
#     </tr>
