# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Model Submission Guide: Titanic Survival Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
# !pip install aimodelshare --upgrade
# !pip install pydot

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/titanic_competition_data-repository:v1')
# Out:
# Downloading [>                                                ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd
training_data=pd.read_csv("titanic_competition_data/training_data.csv")
y_train_labels = training_data['survived']
X_train = training_data.drop(['survived'], axis=1)

X_test=pd.read_csv("titanic_competition_data/test_data.csv")

X_train.head()
# Out:
#    pclass     sex   age     fare embarked
# 0       3    male  28.0   7.2500        S
# 1       3  female  26.0  16.1000        S
# 2       3  female  47.0   7.0000        S
# 3       2    male  57.0  12.3500        Q
# 4       3  female  37.0   9.5875        S

# %% [markdown]
# ## 2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function

# %%
# In this case we use Sklearn's Column transformer in our preprocessor function

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

#Preprocess data using sklearn's Column Transformer approach

# We create the preprocessing pipelines for both numeric and categorical data.
numeric_features = ['age', 'fare']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), #'imputer' names the step
    ('scaler', StandardScaler())])

categorical_features = ['embarked', 'sex', 'pclass']

# Replacing missing values with Modal value and then one-hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Final preprocessor object set up with ColumnTransformer...

preprocess = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# fit preprocessor to your data
preprocess = preprocess.fit(X_train)

# %%
# Here is where we actually write the preprocessor function:

# Write function to transform data with preprocessor 
# In this case we use sklearn's Column transformer in our preprocessor function

def preprocessor(data):
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (1047, 10)

# %% [markdown]
# ## 3. Fit model on preprocessed data and save preprocessor function and model

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(C=10, penalty='l1', solver = 'liblinear')
model.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.778414517669532

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  #Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this Titanic Survival Playground -- make sure to update the apiurl for new competition deployments
apiurl="https://mzq4b9vwq5.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username: ············
# AI Modelshare Password: ···············
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted values (a list of predicted labels "survived" or "died") (Model 1)
prediction_labels = model.predict(preprocessor(X_test))

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 10
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1656

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_c4e60_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 78.6%, transparent 78.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row0_col4, #T_c4e60_row0_col5, #T_c4e60_row0_col6, #T_c4e60_row0_col7, #T_c4e60_row0_col8, #T_c4e60_row0_col9, #T_c4e60_row0_col10, #T_c4e60_row0_col11, #T_c4e60_row0_col12, #T_c4e60_row0_col13, #T_c4e60_row0_col14, #T_c4e60_row0_col15, #T_c4e60_row0_col16, #T_c4e60_row0_col17, #T_c4e60_row0_col18, #T_c4e60_row1_col4, #T_c4e60_row1_col5, #T_c4e60_row1_col6, #T_c4e60_row1_col7, #T_c4e60_row1_col8, #T_c4e60_row1_col9, #T_c4e60_row1_col10, #T_c4e60_row1_col11, #T_c4e60_row1_col12, #T_c4e60_row1_col13, #T_c4e60_row1_col14, #T_c4e60_row1_col15, #T_c4e60_row1_col16, #T_c4e60_row1_col17, #T_c4e60_row1_col18, #T_c4e60_row2_col4, #T_c4e60_row2_col5, #T_c4e60_row2_col6, #T_c4e60_row2_col7, #T_c4e60_row2_col8, #T_c4e60_row2_col9, #T_c4e60_row2_col10, #T_c4e60_row2_col11, #T_c4e60_row2_col12, #T_c4e60_row2_col13, #T_c4e60_row2_col14, #T_c4e60_row2_col15, #T_c4e60_row2_col16, #T_c4e60_row2_col17, #T_c4e60_row2_col18, #T_c4e60_row3_col4, #T_c4e60_row3_col5, #T_c4e60_row3_col6, #T_c4e60_row3_col7, #T_c4e60_row3_col8, #T_c4e60_row3_col9, #T_c4e60_row3_col10, #T_c4e60_row3_col11, #T_c4e60_row3_col12, #T_c4e60_row3_col13, #T_c4e60_row3_col14, #T_c4e60_row3_col15, #T_c4e60_row3_col16, #T_c4e60_row3_col17, #T_c4e60_row3_col18, #T_c4e60_row4_col4, #T_c4e60_row4_col5, #T_c4e60_row4_col6, #T_c4e60_row4_col7, #T_c4e60_row4_col8, #T_c4e60_row4_col9, #T_c4e60_row4_col10, #T_c4e60_row4_col11, #T_c4e60_row4_col12, #T_c4e60_row4_col13, #T_c4e60_row4_col14, #T_c4e60_row4_col15, #T_c4e60_row4_col16, #T_c4e60_row4_col17, #T_c4e60_row4_col18, #T_c4e60_row5_col4, #T_c4e60_row5_col5, #T_c4e60_row5_col6, #T_c4e60_row5_col7, #T_c4e60_row5_col8, #T_c4e60_row5_col9, #T_c4e60_row5_col10, #T_c4e60_row5_col11, #T_c4e60_row5_col12, #T_c4e60_row5_col13, #T_c4e60_row5_col14, #T_c4e60_row5_col15, #T_c4e60_row5_col16, #T_c4e60_row5_col17, #T_c4e60_row5_col18, #T_c4e60_row6_col4, #T_c4e60_row6_col5, #T_c4e60_row6_col6, #T_c4e60_row6_col7, #T_c4e60_row6_col8, #T_c4e60_row6_col9, #T_c4e60_row6_col10, #T_c4e60_row6_col11, #T_c4e60_row6_col12, #T_c4e60_row6_col13, #T_c4e60_row6_col14, #T_c4e60_row6_col15, #T_c4e60_row6_col16, #T_c4e60_row6_col17, #T_c4e60_row6_col18, #T_c4e60_row7_col4, #T_c4e60_row7_col5, #T_c4e60_row7_col6, #T_c4e60_row7_col7, #T_c4e60_row7_col8, #T_c4e60_row7_col9, #T_c4e60_row7_col10, #T_c4e60_row7_col11, #T_c4e60_row7_col12, #T_c4e60_row7_col13, #T_c4e60_row7_col14, #T_c4e60_row7_col15, #T_c4e60_row7_col16, #T_c4e60_row7_col17, #T_c4e60_row7_col18, #T_c4e60_row8_col4, #T_c4e60_row8_col5, #T_c4e60_row8_col6, #T_c4e60_row8_col7, #T_c4e60_row8_col8, #T_c4e60_row8_col9, #T_c4e60_row8_col10, #T_c4e60_row8_col11, #T_c4e60_row8_col12, #T_c4e60_row8_col13, #T_c4e60_row8_col14, #T_c4e60_row8_col15, #T_c4e60_row8_col16, #T_c4e60_row8_col17, #T_c4e60_row8_col18, #T_c4e60_row9_col4, #T_c4e60_row9_col5, #T_c4e60_row9_col6, #T_c4e60_row9_col7, #T_c4e60_row9_col8, #T_c4e60_row9_col9, #T_c4e60_row9_col10, #T_c4e60_row9_col11, #T_c4e60_row9_col12, #T_c4e60_row9_col13, #T_c4e60_row9_col14, #T_c4e60_row9_col15, #T_c4e60_row9_col16, #T_c4e60_row9_col17, #T_c4e60_row9_col18 {
#   text-align: center;
# }
# #T_c4e60_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 76.3%, transparent 76.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 73.0%, transparent 73.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 76.6%, transparent 76.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 72.1%, transparent 72.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 57.3%, transparent 57.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 54.7%, transparent 54.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 54.7%, transparent 54.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 54.7%, transparent 54.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row3_col0, #T_c4e60_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 56.5%, transparent 56.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 62.6%, transparent 62.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 40.3%, transparent 40.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 81.2%, transparent 81.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 51.0%, transparent 51.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 51.5%, transparent 51.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 52.0%, transparent 52.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 51.8%, transparent 51.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row6_col0, #T_c4e60_row7_col0, #T_c4e60_row9_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 55.0%, transparent 55.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row6_col1, #T_c4e60_row7_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 51.7%, transparent 51.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row6_col2, #T_c4e60_row7_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 51.8%, transparent 51.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from sklearn.linear_model import LogisticRegression

model_2 = LogisticRegression(C=.01, penalty='l2')
model_2.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model_2.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.775549188156638

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model_2, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# 100% [................................................................................] 5919 / 5919
# Insert search tags to help users find your model (optional):  x
# Provide any useful notes about your model (optional):  x
# Your model has been submitted as model version 56
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1656

# %%
# Compare two or more models
data=mycompetition.compare_models([1,2], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_d4c05_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_d4c05_row0_col2, #T_d4c05_row0_col3, #T_d4c05_row9_col2, #T_d4c05_row11_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_d4c05_">
#   <caption>Model type: LogisticRegression</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_1</th>
#       <th class="col_heading level0 col3" >model_version_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4c05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4c05_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_d4c05_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_d4c05_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_d4c05_row0_col3" class="data row0 col3" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d4c05_row1_col0" class="data row1 col0" >class_weight</td>
#       <td id="T_d4c05_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_d4c05_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_d4c05_row1_col3" class="data row1 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d4c05_row2_col0" class="data row2 col0" >dual</td>
#       <td id="T_d4c05_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_d4c05_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_d4c05_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d4c05_row3_col0" class="data row3 col0" >fit_intercept</td>
#       <td id="T_d4c05_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_d4c05_row3_col2" class="data row3 col2" >True</td>
#       <td id="T_d4c05_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d4c05_row4_col0" class="data row4 col0" >intercept_scaling</td>
#       <td id="T_d4c05_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_d4c05_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_d4c05_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d4c05_row5_col0" class="data row5 col0" >l1_ratio</td>
#       <td id="T_d4c05_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_d4c05_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_d4c05_row5_col3" class="data row5 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d4c05_row6_col0" class="data row6 col0" >max_iter</td>
#       <td id="T_d4c05_row6_col1" class="data row6 col1" >100</td>
#       <td id="T_d4c05_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_d4c05_row6_col3" class="data row6 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d4c05_row7_col0" class="data row7 col0" >multi_class</td>
#       <td id="T_d4c05_row7_col1" class="data row7 col1" >auto</td>
#       <td id="T_d4c05_row7_col2" class="data row7 col2" >auto</td>
#       <td id="T_d4c05_row7_col3" class="data row7 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d4c05_row8_col0" class="data row8 col0" >n_jobs</td>
#       <td id="T_d4c05_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_d4c05_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_d4c05_row8_col3" class="data row8 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d4c05_row9_col0" class="data row9 col0" >penalty</td>
#       <td id="T_d4c05_row9_col1" class="data row9 col1" >l2</td>
#       <td id="T_d4c05_row9_col2" class="data row9 col2" >l1</td>
#       <td id="T_d4c05_row9_col3" class="data row9 col3" >l2</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d4c05_row10_col0" class="data row10 col0" >random_state</td>
#       <td id="T_d4c05_row10_col1" class="data row10 col1" >None</td>
#       <td id="T_d4c05_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_d4c05_row10_col3" class="data row10 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d4c05_row11_col0" class="data row11 col0" >solver</td>
#       <td id="T_d4c05_row11_col1" class="data row11 col1" >lbfgs</td>
#       <td id="T_d4c05_row11_col2" class="data row11 col2" >liblinear</td>
#       <td id="T_d4c05_row11_col3" class="data row11 col3" >lbfgs</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d4c05_row12_col0" class="data row12 col0" >tol</td>
#       <td id="T_d4c05_row12_col1" class="data row12 col1" >0.000100</td>
#       <td id="T_d4c05_row12_col2" class="data row12 col2" >0.000100</td>
#       <td id="T_d4c05_row12_col3" class="data row12 col3" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d4c05_row13_col0" class="data row13 col0" >verbose</td>
#       <td id="T_d4c05_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_d4c05_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_d4c05_row13_col3" class="data row13 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d4c05_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d4c05_row14_col0" class="data row14 col0" >warm_start</td>
#       <td id="T_d4c05_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_d4c05_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_d4c05_row14_col3" class="data row14 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Submit a third model using GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

param_grid = {'n_estimators': np.arange(100, 300, 50),'max_depth':[1, 3, 5]} #np.arange creates sequence of numbers for each k value

gridmodel = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=10)

#use meta model methods to fit score and predict model:
gridmodel.fit(preprocessor(X_train), y_train_labels)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
# Out:
# best mean cross-validation score: 0.799
# best parameters: {'max_depth': 5, 'n_estimators': 100}

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(gridmodel, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("gridmodel.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted values
prediction_labels = gridmodel.predict(preprocessor(X_test))

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = "gridmodel.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 100% [................................................................................] 5919 / 5919
# Insert search tags to help users find your model (optional):  x
# Provide any useful notes about your model (optional):
# Your model has been submitted as model version 57
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1656

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_b8bef_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 78.6%, transparent 78.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b8bef_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b8bef_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b8bef_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_b8bef_row0_col4, #T_b8bef_row0_col5, #T_b8bef_row0_col6, #T_b8bef_row0_col7, #T_b8bef_row0_col8, #T_b8bef_row0_col9, #T_b8bef_row0_col10, #T_b8bef_row0_col11, #T_b8bef_row0_col12, #T_b8bef_row0_col13, #T_b8bef_row0_col14, #T_b8bef_row0_col15, #T_b8bef_row0_col16, #T_b8bef_row0_col17, #T_b8bef_row0_col18, #T_b8bef_row0_col19, #T_b8bef_row0_col20, #T_b8bef_row0_col21, #T_b8bef_row0_col22, #T_b8bef_row0_col23, #T_b8bef_row0_col24, #T_b8bef_row1_col4, #T_b8bef_row1_col5, #T_b8bef_row1_col6, #T_b8bef_row1_col7, #T_b8bef_row1_col8, #T_b8bef_row1_col9, #T_b8bef_row1_col10, #T_b8bef_row1_col11, #T_b8bef_row1_col12, #T_b8bef_row1_col13, #T_b8bef_row1_col14, #T_b8bef_row1_col15, #T_b8bef_row1_col16, #T_b8bef_row1_col17, #T_b8bef_row1_col18, #T_b8bef_row1_col19, #T_b8bef_row1_col20, #T_b8bef_row1_col21, #T_b8bef_row1_col22, #T_b8bef_row1_col23, #T_b8bef_row1_col24, #T_b8bef_row2_col4, #T_b8bef_row2_col5, #T_b8bef_row2_col6, #T_b8bef_row2_col7, #T_b8bef_row2_col8, #T_b8bef_row2_col9, #T_b8bef_row2_col10, #T_b8bef_row2_col11, #T_b8bef_row2_col12, #T_b8bef_row2_col13, #T_b8bef_row2_col14, #T_b8bef_row2_col15, #T_b8bef_row2_col16, #T_b8bef_row2_col17, #T_b8bef_row2_col18, #T_b8bef_row2_col19, #T_b8bef_row2_col20, #T_b8bef_row2_col21, #T_b8bef_row2_col22, #T_b8bef_row2_col23, #T_b8bef_row2_col24, #T_b8bef_row3_col4, #T_b8bef_row3_col5, #T_b8bef_row3_col6, #T_b8bef_row3_col7, #T_b8bef_row3_col8, #T_b8bef_row3_col9, #T_b8bef_row3_col10, #T_b8bef_row3_col11, #T_b8bef_row3_col12, #T_b8bef_row3_col13, #T_b8bef_row3_col14, #T_b8bef_row3_col15, #T_b8bef_row3_col16, #T_b8bef_row3_col17, #T_b8bef_row3_col18, #T_b8bef_row3_col19, #T_b8bef_row3_col20, #T_b8bef_row3_col21, #T_b8bef_row3_col22, #T_b8bef_row3_col23, #T_b8bef_row3_col24, #T_b8bef_row4_col4, #T_b8bef_row4_col5, #T_b8bef_row4_col6, #T_b8bef_row4_col7, #T_b8bef_row4_col8, #T_b8bef_row4_col9, #T_b8bef_row4_col10, #T_b8bef_row4_col11, #T_b8bef_row4_col12, #T_b8bef_row4_col13, #T_b8bef_row4_col14, #T_b8bef_row4_col15, #T_b8bef_row4_col16, #T_b8bef_row4_col17, #T_b8bef_row4_col18, #T_b8bef_row4_col19, #T_b8bef_row4_col20, #T_b8bef_row4_col21, #T_b8bef_row4_col22, #T_b8bef_row4_col23, #T_b8bef_row4_col24, #T_b8bef_row5_col4, #T_b8bef_row5_col5, #T_b8bef_row5_col6, #T_b8bef_row5_col7, #T_b8bef_row5_col8, #T_b8bef_row5_col9, #T_b8bef_row5_col10, #T_b8bef_row5_col11, #T_b8bef_row5_col12, #T_b8bef_row5_col13, #T_b8bef_row5_col14, #T_b8bef_row5_col15, #T_b8bef_row5_col16, #T_b8bef_row5_col17, #T_b8bef_row5_col18, #T_b8bef_row5_col19, #T_b8bef_row5_col20, #T_b8bef_row5_col21, #T_b8bef_row5_col22, #T_b8bef_row5_col23, #T_b8bef_row5_col24, #T_b8bef_row6_col4, #T_b8bef_row6_col5, #T_b8bef_row6_col6, #T_b8bef_row6_col7, #T_b8bef_row6_col8, #T_b8bef_row6_col9, #T_b8bef_row6_col10, #T_b8bef_row6_col11, #T_b8bef_row6_col12, #T_b8bef_row6_col13, #T_b8bef_row6_col14, #T_b8bef_row6_col15, #T_b8bef_row6_col16, #T_b8bef_row6_col17, #T_b8bef_row6_col18, #T_b8bef_row6_col19, #T_b8bef_row6_col20, #T_b8bef_row6_col21, #T_b8bef_row6_col22, #T_b8bef_row6_col23, #T_b8bef_row6_col24, #T_b8bef_row7_col4, #T_b8bef_row7_col5, #T_b8bef_row7_col6, #T_b8bef_row7_col7, #T_b8bef_row7_col8, #T_b8bef_row7_col9, #T_b8bef_row7_col10, #T_b8bef_row7_col11, #T_b8bef_row7_col12, #T_b8bef_row7_col13, #T_b8bef_row7_col14, #T_b8bef_row7_col15, #T_b8bef_row7_col16, #T_b8bef_row7_col17, #T_b8bef_row7_col18, #T_b8bef_row7_col19, #T_b8bef_row7_col20, #T_b8bef_row7_col21, #T_b8bef_row7_col22, #T_b8bef_row7_col23, #T_b8bef_row7_col24, #T_b8bef_row8_col4, #T_b8bef_row8_col5, #T_b8bef_row8_col6, #T_b8bef_row8_col7, #T_b8bef_row8_col8, #T_b8bef_row8_col9, #T_b8bef_row8_col10, #T_b8bef_row8_col11, #T_b8bef_row8_col12, #T_b8bef_row8_col13, #T_b8bef_row8_col14, #T_b8bef_row8_col15, #T_b8bef_row8_col16, #T_b8bef_row8_col17, #T_b8bef_row8_col18, #T_b8bef_row8_col19, #T_b8bef_row8_col20, #T_b8bef_row8_col21, #T_b8bef_row8_col22, #T_b8bef_row8_col23, #T_b8bef_row8_col24, #T_b8bef_row9_col4, #T_b8bef_row9_col5, #T_b8bef_row9_col6, #T_b8bef_row9_col7, #T_b8 ...

# %%
# Compare two or more models
data=mycompetition.compare_models([2,3], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_0570c_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_0570c_row0_col2, #T_0570c_row0_col3, #T_0570c_row9_col3, #T_0570c_row11_col3 {
#   background: tomato;
# }
# </style>
# <table id="T_0570c_">
#   <caption>Model type: LogisticRegression</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_2</th>
#       <th class="col_heading level0 col3" >model_version_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0570c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0570c_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_0570c_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_0570c_row0_col2" class="data row0 col2" >0.010000</td>
#       <td id="T_0570c_row0_col3" class="data row0 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0570c_row1_col0" class="data row1 col0" >class_weight</td>
#       <td id="T_0570c_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_0570c_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_0570c_row1_col3" class="data row1 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0570c_row2_col0" class="data row2 col0" >dual</td>
#       <td id="T_0570c_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_0570c_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_0570c_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0570c_row3_col0" class="data row3 col0" >fit_intercept</td>
#       <td id="T_0570c_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_0570c_row3_col2" class="data row3 col2" >True</td>
#       <td id="T_0570c_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0570c_row4_col0" class="data row4 col0" >intercept_scaling</td>
#       <td id="T_0570c_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_0570c_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_0570c_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0570c_row5_col0" class="data row5 col0" >l1_ratio</td>
#       <td id="T_0570c_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_0570c_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_0570c_row5_col3" class="data row5 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0570c_row6_col0" class="data row6 col0" >max_iter</td>
#       <td id="T_0570c_row6_col1" class="data row6 col1" >100</td>
#       <td id="T_0570c_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_0570c_row6_col3" class="data row6 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0570c_row7_col0" class="data row7 col0" >multi_class</td>
#       <td id="T_0570c_row7_col1" class="data row7 col1" >auto</td>
#       <td id="T_0570c_row7_col2" class="data row7 col2" >auto</td>
#       <td id="T_0570c_row7_col3" class="data row7 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0570c_row8_col0" class="data row8 col0" >n_jobs</td>
#       <td id="T_0570c_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_0570c_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_0570c_row8_col3" class="data row8 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0570c_row9_col0" class="data row9 col0" >penalty</td>
#       <td id="T_0570c_row9_col1" class="data row9 col1" >l2</td>
#       <td id="T_0570c_row9_col2" class="data row9 col2" >l2</td>
#       <td id="T_0570c_row9_col3" class="data row9 col3" >l1</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0570c_row10_col0" class="data row10 col0" >random_state</td>
#       <td id="T_0570c_row10_col1" class="data row10 col1" >None</td>
#       <td id="T_0570c_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_0570c_row10_col3" class="data row10 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0570c_row11_col0" class="data row11 col0" >solver</td>
#       <td id="T_0570c_row11_col1" class="data row11 col1" >lbfgs</td>
#       <td id="T_0570c_row11_col2" class="data row11 col2" >lbfgs</td>
#       <td id="T_0570c_row11_col3" class="data row11 col3" >liblinear</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0570c_row12_col0" class="data row12 col0" >tol</td>
#       <td id="T_0570c_row12_col1" class="data row12 col1" >0.000100</td>
#       <td id="T_0570c_row12_col2" class="data row12 col2" >0.000100</td>
#       <td id="T_0570c_row12_col3" class="data row12 col3" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0570c_row13_col0" class="data row13 col0" >verbose</td>
#       <td id="T_0570c_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_0570c_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_0570c_row13_col3" class="data row13 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_0570c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0570c_row14_col0" class="data row14 col0" >warm_start</td>
#       <td id="T_0570c_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_0570c_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_0570c_row14_col3" class="data row14 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

#Example code to fit model:
model = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0,
    max_depth=1, random_state=0).fit(preprocessor(X_train), y_train_labels)
model.score(preprocessor(X_train), y_train_labels)

# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values (a list of predicted labels "real" or "fake")
prediction_labels = model.predict(preprocessor(X_test))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 100% [................................................................................] 5919 / 5919
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
# Your model has been submitted as model version 58
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1656
