# %% [markdown]
# <p align="center"><img width="50%" src="https://aimodelsharecontent.s3.amazonaws.com/aimodshare_banner.jpg" /></p>
#
#
# ---

# %% [markdown]
# ## Model Submission Guide: Titanic Survival Competition
# Let's share our models to a centralized leaderboard, so that we can collaborate and learn from the model experimentation process...
#
# **Instructions:**
# 1.   Get data in and set up X_train / X_test / y_train
# 2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function
# 3. Fit model on preprocessed data and save preprocessor function and model
# 4. Generate predictions from X_test data and submit model to competition
# 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ## 1. Get data in and set up X_train, X_test, y_train objects

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade
# Out:
# Requirement already satisfied: aimodelshare in c:\users\administrator\appdata\roaming\python\python39\site-packages (0.0.100)
# Requirement already satisfied: wget==3.2 in c:\programdata\anaconda3\lib\site-packages (from aimodelshare) (3.2)
# Requirement already satisfied: onnxruntime>=1.7.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.11.1)
# Requirement already satisfied: xgboost>=0.90 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.6.1)
# Requirement already satisfied: scikit-learn==0.24.2 in c:\programdata\anaconda3\lib\site-packages (from aimodelshare) (0.24.2)
# Requirement already satisfied: shortuuid>=1.0.8 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.0.9)
# Requirement already satisfied: torch>=1.8.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.11.0)
# Requirement already satisfied: skl2onnx>=1.8.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.11.2)
# Requirement already satisfied: onnxconverter-common>=1.7.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.9.0)
# Requirement already satisfied: PyJWT==2.2.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (2.2.0)
# Requirement already satisfied: Pympler==0.9 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (0.9)
# Requirement already satisfied: onnx>=1.9.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.12.0)
# Requirement already satisfied: tensorflow>=2.5.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (2.9.1)
# Requirement already satisfied: keras2onnx>=1.7.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.7.0)
# Requirement already satisfied: docker==5.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (5.0.0)
# Requirement already satisfied: seaborn>=0.11.2 in c:\programdata\anaconda3\lib\site-packages (from aimodelshare) (0.11.2)
# Requirement already satisfied: urllib3==1.25.11 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.25.11)
# Requirement already satisfied: boto3==1.18.2 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.18.2)
# Requirement already satisfied: onnxmltools>=1.6.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.11.1)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.6.3)
# Requirement already satisfied: tf2onnx in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.11.1)
# Requirement already satisfied: botocore==1.21.2 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from aimodelshare) (1.21.2)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from astunparse==1.6.3->aimodelshare) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse==1.6.3->aimodelshare) (0.37.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from boto3==1.18.2->aimodelshare) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from boto3==1.18.2->aimodelshare) (0.5.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\programdata\anaconda3\lib\site-packages (from botocore==1.21.2->aimodelshare) (2.8.2)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from docker==5.0.0->aimodelshare) (1.3.2)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in c:\programdata\anaconda3\lib\site-packages (from docker==5.0.0->aimodelshare) (2.26.0)
# Requirement already satisfied: pywin32==227 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from docker==5.0.0->aimodelshare) (227)
# Requirement already satisfied: scipy>=0.19.1 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn==0.24.2->aimodelshare) (1.7.1)
# Requirement already satisfied: joblib>=0.11 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn==0.24.2->aimodelshare) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from scikit-learn==0.24.2->aimodelshare) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn==0.24.2->aimodelshare) (2.2.0)
# Requirement already satisfied: fire in c:\users\administrator\appdata\roaming\python\python39\site-packages (from keras2onnx>=1.7.0->aimodelshare) (0.4.0)
# Requirement already satisfied: protobuf in c:\users\administrator\appdata\roaming\python\python39\site-packages (from keras2onnx>=1.7.0->aimodelshare) (3.19.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in c:\programdata\anaconda3\lib\site-packages (from onnx>=1.9.0->aimodelshare) (3.10.0.2)
# Requirement already satisfied: flatbuffers in c:\users\administrator\appdata\roaming\python\python39\site-packages (from onnxruntime>=1.7.0->aimodelshare) (1.12)
# Requirement already satisfied: pandas>=0.23 in c:\programdata\anaconda3\lib\site-packages (from seaborn>=0.11.2->aimodelshare) (1.3.4)
# Requirement already satisfied: matplotlib>=2.2 in c:\programdata\anaconda3\lib\site-packages (from seaborn>=0.11.2->aimodelshare) (3.4.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (3.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (1.46.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=2.5.0->aimodelshare) (1.1.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (2.9.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=2.5.0->aimodelshare) (3.2.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (0.26.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (2.9.0)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=2.5.0->aimodelshare) (62.1.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (2.9.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (0.2.0)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=2.5.0->aimodelshare) (21.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow>=2.5.0->aimodelshare) (1.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (14.0.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorflow>=2.5.0->aimodelshare) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=2.2->seaborn>=0.11.2->aimodelshare) (1.3.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas>=0.23->seaborn>=0.11.2->aimodelshare) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (3.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (2.8.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\programdata\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\administrator\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.5.0->aimodelshare) (3.2.0)

# %%
# Get competition data
from aimodelshare import download_data
download_data('public.ecr.aws/y2e2a1d6/titanic_competition_data-repository:v1')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.25.11) or chardet (2.0.3)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# Downloading [>                                                ]
#
# Data downloaded successfully.

# %%
# Separate data into X_train, y_train, and X_test
import pandas as pd
training_data=pd.read_csv("titanic_competition_data/training_data.csv")
y_train_labels = training_data['survived']
X_train = training_data.drop(['survived'], axis=1)

X_test=pd.read_csv("titanic_competition_data/test_data.csv")

X_train.head()
# Out:
#    pclass     sex   age     fare embarked
# 0       3    male  28.0   7.2500        S
# 1       3  female  26.0  16.1000        S
# 2       3  female  47.0   7.0000        S
# 3       2    male  57.0  12.3500        Q
# 4       3  female  37.0   9.5875        S

# %% [markdown]
# ##2.   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function

# %%
# In this case we use Sklearn's Column transformer in our preprocessor function

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

#Preprocess data using sklearn's Column Transformer approach

# We create the preprocessing pipelines for both numeric and categorical data.
numeric_features = ['age', 'fare']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), #'imputer' names the step
    ('scaler', StandardScaler())])

categorical_features = ['embarked', 'sex', 'pclass']

# Replacing missing values with Modal value and then one-hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# Final preprocessor object set up with ColumnTransformer...

preprocess = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# fit preprocessor to your data
preprocess = preprocess.fit(X_train)

# %%
# Here is where we actually write the preprocessor function:

# Write function to transform data with preprocessor 
# In this case we use sklearn's Column transformer in our preprocessor function

def preprocessor(data):
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (1047, 10)

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(C=10, penalty='l1', solver = 'liblinear')
model.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.778414517669532

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# #### Save model to local ".onnx" file

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

# Check how many preprocessed input features are there?
from skl2onnx.common.data_types import FloatTensorType

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  #Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this Titanic Survival Playground -- make sure to update the apiurl for new competition deployments
apiurl="https://mzq4b9vwq5.execute-api.us-east-1.amazonaws.com/prod/m"

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:··········
# AI Modelshare Password:··········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted values (a list of predicted labels "survived" or "died") (Model 1)
prediction_labels = model.predict(preprocessor(X_test))

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 10
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1656

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_c4e60_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 78.6%, transparent 78.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row0_col4, #T_c4e60_row0_col5, #T_c4e60_row0_col6, #T_c4e60_row0_col7, #T_c4e60_row0_col8, #T_c4e60_row0_col9, #T_c4e60_row0_col10, #T_c4e60_row0_col11, #T_c4e60_row0_col12, #T_c4e60_row0_col13, #T_c4e60_row0_col14, #T_c4e60_row0_col15, #T_c4e60_row0_col16, #T_c4e60_row0_col17, #T_c4e60_row0_col18, #T_c4e60_row1_col4, #T_c4e60_row1_col5, #T_c4e60_row1_col6, #T_c4e60_row1_col7, #T_c4e60_row1_col8, #T_c4e60_row1_col9, #T_c4e60_row1_col10, #T_c4e60_row1_col11, #T_c4e60_row1_col12, #T_c4e60_row1_col13, #T_c4e60_row1_col14, #T_c4e60_row1_col15, #T_c4e60_row1_col16, #T_c4e60_row1_col17, #T_c4e60_row1_col18, #T_c4e60_row2_col4, #T_c4e60_row2_col5, #T_c4e60_row2_col6, #T_c4e60_row2_col7, #T_c4e60_row2_col8, #T_c4e60_row2_col9, #T_c4e60_row2_col10, #T_c4e60_row2_col11, #T_c4e60_row2_col12, #T_c4e60_row2_col13, #T_c4e60_row2_col14, #T_c4e60_row2_col15, #T_c4e60_row2_col16, #T_c4e60_row2_col17, #T_c4e60_row2_col18, #T_c4e60_row3_col4, #T_c4e60_row3_col5, #T_c4e60_row3_col6, #T_c4e60_row3_col7, #T_c4e60_row3_col8, #T_c4e60_row3_col9, #T_c4e60_row3_col10, #T_c4e60_row3_col11, #T_c4e60_row3_col12, #T_c4e60_row3_col13, #T_c4e60_row3_col14, #T_c4e60_row3_col15, #T_c4e60_row3_col16, #T_c4e60_row3_col17, #T_c4e60_row3_col18, #T_c4e60_row4_col4, #T_c4e60_row4_col5, #T_c4e60_row4_col6, #T_c4e60_row4_col7, #T_c4e60_row4_col8, #T_c4e60_row4_col9, #T_c4e60_row4_col10, #T_c4e60_row4_col11, #T_c4e60_row4_col12, #T_c4e60_row4_col13, #T_c4e60_row4_col14, #T_c4e60_row4_col15, #T_c4e60_row4_col16, #T_c4e60_row4_col17, #T_c4e60_row4_col18, #T_c4e60_row5_col4, #T_c4e60_row5_col5, #T_c4e60_row5_col6, #T_c4e60_row5_col7, #T_c4e60_row5_col8, #T_c4e60_row5_col9, #T_c4e60_row5_col10, #T_c4e60_row5_col11, #T_c4e60_row5_col12, #T_c4e60_row5_col13, #T_c4e60_row5_col14, #T_c4e60_row5_col15, #T_c4e60_row5_col16, #T_c4e60_row5_col17, #T_c4e60_row5_col18, #T_c4e60_row6_col4, #T_c4e60_row6_col5, #T_c4e60_row6_col6, #T_c4e60_row6_col7, #T_c4e60_row6_col8, #T_c4e60_row6_col9, #T_c4e60_row6_col10, #T_c4e60_row6_col11, #T_c4e60_row6_col12, #T_c4e60_row6_col13, #T_c4e60_row6_col14, #T_c4e60_row6_col15, #T_c4e60_row6_col16, #T_c4e60_row6_col17, #T_c4e60_row6_col18, #T_c4e60_row7_col4, #T_c4e60_row7_col5, #T_c4e60_row7_col6, #T_c4e60_row7_col7, #T_c4e60_row7_col8, #T_c4e60_row7_col9, #T_c4e60_row7_col10, #T_c4e60_row7_col11, #T_c4e60_row7_col12, #T_c4e60_row7_col13, #T_c4e60_row7_col14, #T_c4e60_row7_col15, #T_c4e60_row7_col16, #T_c4e60_row7_col17, #T_c4e60_row7_col18, #T_c4e60_row8_col4, #T_c4e60_row8_col5, #T_c4e60_row8_col6, #T_c4e60_row8_col7, #T_c4e60_row8_col8, #T_c4e60_row8_col9, #T_c4e60_row8_col10, #T_c4e60_row8_col11, #T_c4e60_row8_col12, #T_c4e60_row8_col13, #T_c4e60_row8_col14, #T_c4e60_row8_col15, #T_c4e60_row8_col16, #T_c4e60_row8_col17, #T_c4e60_row8_col18, #T_c4e60_row9_col4, #T_c4e60_row9_col5, #T_c4e60_row9_col6, #T_c4e60_row9_col7, #T_c4e60_row9_col8, #T_c4e60_row9_col9, #T_c4e60_row9_col10, #T_c4e60_row9_col11, #T_c4e60_row9_col12, #T_c4e60_row9_col13, #T_c4e60_row9_col14, #T_c4e60_row9_col15, #T_c4e60_row9_col16, #T_c4e60_row9_col17, #T_c4e60_row9_col18 {
#   text-align: center;
# }
# #T_c4e60_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 76.3%, transparent 76.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 73.0%, transparent 73.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 76.6%, transparent 76.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 72.1%, transparent 72.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 57.3%, transparent 57.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 54.7%, transparent 54.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 54.7%, transparent 54.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 54.7%, transparent 54.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row3_col0, #T_c4e60_row5_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 56.5%, transparent 56.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 62.6%, transparent 62.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 40.3%, transparent 40.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 81.2%, transparent 81.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 51.0%, transparent 51.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row5_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 51.5%, transparent 51.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row5_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 52.0%, transparent 52.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row5_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 51.8%, transparent 51.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row6_col0, #T_c4e60_row7_col0, #T_c4e60_row9_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 55.0%, transparent 55.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row6_col1, #T_c4e60_row7_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 51.7%, transparent 51.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_c4e60_row6_col2, #T_c4e60_row7_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 51.8%, transparent 51.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %%
# Train and submit model 2 using same preprocessor (note that you could save a new preprocessor, but we will use the same one for this example).
from sklearn.linear_model import LogisticRegression

model_2 = LogisticRegression(C=.01, penalty='l2')
model_2.fit(preprocessor(X_train), y_train_labels) # Fitting to the training set.
model_2.score(preprocessor(X_train), y_train_labels) # Fit score, 0-1 scale.
# Out:
# 0.775549188156638

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model_2, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(preprocessor(X_test))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 11
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1656

# %%
# Compare two or more models
data=mycompetition.compare_models([1,2], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_903b0_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_903b0_row0_col2, #T_903b0_row0_col3, #T_903b0_row9_col2, #T_903b0_row11_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_903b0_">
#   <caption>Model type: LogisticRegression</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_1</th>
#       <th class="col_heading level0 col3" >model_version_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_903b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_903b0_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_903b0_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_903b0_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_903b0_row0_col3" class="data row0 col3" >0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_903b0_row1_col0" class="data row1 col0" >class_weight</td>
#       <td id="T_903b0_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_903b0_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_903b0_row1_col3" class="data row1 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_903b0_row2_col0" class="data row2 col0" >dual</td>
#       <td id="T_903b0_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_903b0_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_903b0_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_903b0_row3_col0" class="data row3 col0" >fit_intercept</td>
#       <td id="T_903b0_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_903b0_row3_col2" class="data row3 col2" >True</td>
#       <td id="T_903b0_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_903b0_row4_col0" class="data row4 col0" >intercept_scaling</td>
#       <td id="T_903b0_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_903b0_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_903b0_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_903b0_row5_col0" class="data row5 col0" >l1_ratio</td>
#       <td id="T_903b0_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_903b0_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_903b0_row5_col3" class="data row5 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_903b0_row6_col0" class="data row6 col0" >max_iter</td>
#       <td id="T_903b0_row6_col1" class="data row6 col1" >100</td>
#       <td id="T_903b0_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_903b0_row6_col3" class="data row6 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_903b0_row7_col0" class="data row7 col0" >multi_class</td>
#       <td id="T_903b0_row7_col1" class="data row7 col1" >auto</td>
#       <td id="T_903b0_row7_col2" class="data row7 col2" >auto</td>
#       <td id="T_903b0_row7_col3" class="data row7 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_903b0_row8_col0" class="data row8 col0" >n_jobs</td>
#       <td id="T_903b0_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_903b0_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_903b0_row8_col3" class="data row8 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_903b0_row9_col0" class="data row9 col0" >penalty</td>
#       <td id="T_903b0_row9_col1" class="data row9 col1" >l2</td>
#       <td id="T_903b0_row9_col2" class="data row9 col2" >l1</td>
#       <td id="T_903b0_row9_col3" class="data row9 col3" >l2</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_903b0_row10_col0" class="data row10 col0" >random_state</td>
#       <td id="T_903b0_row10_col1" class="data row10 col1" >None</td>
#       <td id="T_903b0_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_903b0_row10_col3" class="data row10 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_903b0_row11_col0" class="data row11 col0" >solver</td>
#       <td id="T_903b0_row11_col1" class="data row11 col1" >lbfgs</td>
#       <td id="T_903b0_row11_col2" class="data row11 col2" >liblinear</td>
#       <td id="T_903b0_row11_col3" class="data row11 col3" >lbfgs</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_903b0_row12_col0" class="data row12 col0" >tol</td>
#       <td id="T_903b0_row12_col1" class="data row12 col1" >0.000100</td>
#       <td id="T_903b0_row12_col2" class="data row12 col2" >0.000100</td>
#       <td id="T_903b0_row12_col3" class="data row12 col3" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_903b0_row13_col0" class="data row13 col0" >verbose</td>
#       <td id="T_903b0_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_903b0_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_903b0_row13_col3" class="data row13 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_903b0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_903b0_row14_col0" class="data row14 col0" >warm_start</td>
#       <td id="T_903b0_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_903b0_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_903b0_row14_col3" class="data row14 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Submit a third model using GridSearchCV

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

param_grid = {'n_estimators': np.arange(100, 300, 500),'max_depth':[1, 3, 5]} #np.arange creates sequence of numbers for each k value

gridmodel = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=10)

#use meta model methods to fit score and predict model:
gridmodel.fit(preprocessor(X_train), y_train_labels)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
# Out:
# best mean cross-validation score: 0.794
# best parameters: {'max_depth': 5, 'n_estimators': 100}

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(gridmodel, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("gridmodel.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 3: 

#-- Generate predicted values
prediction_labels = gridmodel.predict(preprocessor(X_test))

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = "gridmodel.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 12
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1656

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_ca9f2_row0_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 78.6%, transparent 78.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row0_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row0_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row0_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 77.4%, transparent 77.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row0_col4, #T_ca9f2_row0_col5, #T_ca9f2_row0_col6, #T_ca9f2_row0_col7, #T_ca9f2_row0_col8, #T_ca9f2_row0_col9, #T_ca9f2_row0_col10, #T_ca9f2_row0_col11, #T_ca9f2_row1_col4, #T_ca9f2_row1_col5, #T_ca9f2_row1_col6, #T_ca9f2_row1_col7, #T_ca9f2_row1_col8, #T_ca9f2_row1_col9, #T_ca9f2_row1_col10, #T_ca9f2_row1_col11, #T_ca9f2_row2_col4, #T_ca9f2_row2_col5, #T_ca9f2_row2_col6, #T_ca9f2_row2_col7, #T_ca9f2_row2_col8, #T_ca9f2_row2_col9, #T_ca9f2_row2_col10, #T_ca9f2_row2_col11, #T_ca9f2_row3_col4, #T_ca9f2_row3_col5, #T_ca9f2_row3_col6, #T_ca9f2_row3_col7, #T_ca9f2_row3_col8, #T_ca9f2_row3_col9, #T_ca9f2_row3_col10, #T_ca9f2_row3_col11, #T_ca9f2_row4_col4, #T_ca9f2_row4_col5, #T_ca9f2_row4_col6, #T_ca9f2_row4_col7, #T_ca9f2_row4_col8, #T_ca9f2_row4_col9, #T_ca9f2_row4_col10, #T_ca9f2_row4_col11 {
#   text-align: center;
# }
# #T_ca9f2_row1_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 76.3%, transparent 76.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row1_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 73.0%, transparent 73.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row1_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 76.6%, transparent 76.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row1_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 72.1%, transparent 72.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row2_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 56.5%, transparent 56.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row2_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 51.5%, transparent 51.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row2_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 52.0%, transparent 52.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row2_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 51.8%, transparent 51.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row3_col0, #T_ca9f2_row4_col0 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f5f8d6 55.0%, transparent 55.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row3_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 51.7%, transparent 51.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row3_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 51.8%, transparent 51.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row3_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 51.7%, transparent 51.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row4_col1 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#c778c8 47.3%, transparent 47.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row4_col2 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#ff4971 48.2%, transparent 48.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_ca9f2_row4_col3 {
#   text-align: center;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#aadbaa 48.7%, transparent 48.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_ca9f2_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >accuracy</th>
#       <th class="col_heading level0 col1" >f1_score</th>
#       <th class="col_heading level0 col2" >precision</th>
#       <th class="col_heading level0 col3" >recall</th>
#       <th class="col_heading level0 col4" >ml_framework</th>
#       <th class="col_heading level0 col5" >transfer_learning</th>
#       <th class="col_heading level0 col6" >deep_learning</th>
#       <th class="col_heading level0 col7" >model_type</th>
#       <th class="col_heading level0 col8" >num_params</th>
#       <th class="col_heading level0 col9" >optimizer</th>
#       <th class="col_heading level0 col10" >username</th>
#       <th class="col_heading level0 col11" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca9f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca9f2_row0_col0" class="data row0 col0" >78.63%</td>
#       <td id="T_ca9f2_row0_col1" class="data row0 col1" >77.36%</td>
#       <td id="T_ca9f2_row0_col2" class="data row0 col2" >77.36%</td>
#       <td id="T_ca9f2_row0_col3" class="data row0 col3" >77.36%</td>
#       <td id="T_ca9f2_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_ca9f2_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_ca9f2_row0_col6" class="data row0 col6" >False</td>
#       <td id="T_ca9f2_row0_col7" class="data row0 col7" >LogisticRegression</td>
#       <td id="T_ca9f2_row0_col8" class="data row0 col8" >10.000000</td>
#       <td id="T_ca9f2_row0_col9" class="data row0 col9" >liblinear</td>
#       <td id="T_ca9f2_row0_col10" class="data row0 col10" >AIModelShare</td>
#       <td id="T_ca9f2_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ca9f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca9f2_row1_col0" class="data row1 col0" >76.34%</td>
#       <td id="T_ca9f2_row1_col1" class="data row1 col1" >73.01%</td>
#       <td id="T_ca9f2_row1_col2" class="data row1 col2" >76.59%</td>
#       <td id="T_ca9f2_row1_col3" class="data row1 col3" >72.06%</td>
#       <td id="T_ca9f2_row1_col4" class="data row1 col4" >sklearn</td>
#       <td id="T_ca9f2_row1_col5" class="data row1 col5" >False</td>
#       <td id="T_ca9f2_row1_col6" class="data row1 col6" >False</td>
#       <td id="T_ca9f2_row1_col7" class="data row1 col7" >LogisticRegression</td>
#       <td id="T_ca9f2_row1_col8" class="data row1 col8" >10.000000</td>
#       <td id="T_ca9f2_row1_col9" class="data row1 col9" >lbfgs</td>
#       <td id="T_ca9f2_row1_col10" class="data row1 col10" >AIModelShare</td>
#       <td id="T_ca9f2_row1_col11" class="data row1 col11" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ca9f2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca9f2_row2_col0" class="data row2 col0" >56.49%</td>
#       <td id="T_ca9f2_row2_col1" class="data row2 col1" >51.50%</td>
#       <td id="T_ca9f2_row2_col2" class="data row2 col2" >52.03%</td>
#       <td id="T_ca9f2_row2_col3" class="data row2 col3" >51.80%</td>
#       <td id="T_ca9f2_row2_col4" class="data row2 col4" >sklearn</td>
#       <td id="T_ca9f2_row2_col5" class="data row2 col5" >False</td>
#       <td id="T_ca9f2_row2_col6" class="data row2 col6" >False</td>
#       <td id="T_ca9f2_row2_col7" class="data row2 col7" >RandomForestClassifier</td>
#       <td id="T_ca9f2_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_ca9f2_row2_col9" class="data row2 col9" >nan</td>
#       <td id="T_ca9f2_row2_col10" class="data row2 col10" >AIModelShare</td>
#       <td id="T_ca9f2_row2_col11" class="data row2

# %%
# Compare two or more models
data=mycompetition.compare_models([2,3], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_8c489_ caption {
#   color: black;
#   font-size: 18px;
# }
# #T_8c489_row0_col2, #T_8c489_row0_col3, #T_8c489_row9_col3, #T_8c489_row11_col3 {
#   background: tomato;
# }
# </style>
# <table id="T_8c489_">
#   <caption>Model type: LogisticRegression</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >param_name</th>
#       <th class="col_heading level0 col1" >default_value</th>
#       <th class="col_heading level0 col2" >model_version_2</th>
#       <th class="col_heading level0 col3" >model_version_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c489_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c489_row0_col0" class="data row0 col0" >C</td>
#       <td id="T_8c489_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_8c489_row0_col2" class="data row0 col2" >0.010000</td>
#       <td id="T_8c489_row0_col3" class="data row0 col3" >10</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8c489_row1_col0" class="data row1 col0" >class_weight</td>
#       <td id="T_8c489_row1_col1" class="data row1 col1" >None</td>
#       <td id="T_8c489_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_8c489_row1_col3" class="data row1 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8c489_row2_col0" class="data row2 col0" >dual</td>
#       <td id="T_8c489_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_8c489_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_8c489_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8c489_row3_col0" class="data row3 col0" >fit_intercept</td>
#       <td id="T_8c489_row3_col1" class="data row3 col1" >True</td>
#       <td id="T_8c489_row3_col2" class="data row3 col2" >True</td>
#       <td id="T_8c489_row3_col3" class="data row3 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8c489_row4_col0" class="data row4 col0" >intercept_scaling</td>
#       <td id="T_8c489_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_8c489_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_8c489_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8c489_row5_col0" class="data row5 col0" >l1_ratio</td>
#       <td id="T_8c489_row5_col1" class="data row5 col1" >None</td>
#       <td id="T_8c489_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_8c489_row5_col3" class="data row5 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8c489_row6_col0" class="data row6 col0" >max_iter</td>
#       <td id="T_8c489_row6_col1" class="data row6 col1" >100</td>
#       <td id="T_8c489_row6_col2" class="data row6 col2" >100</td>
#       <td id="T_8c489_row6_col3" class="data row6 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8c489_row7_col0" class="data row7 col0" >multi_class</td>
#       <td id="T_8c489_row7_col1" class="data row7 col1" >auto</td>
#       <td id="T_8c489_row7_col2" class="data row7 col2" >auto</td>
#       <td id="T_8c489_row7_col3" class="data row7 col3" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8c489_row8_col0" class="data row8 col0" >n_jobs</td>
#       <td id="T_8c489_row8_col1" class="data row8 col1" >None</td>
#       <td id="T_8c489_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_8c489_row8_col3" class="data row8 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8c489_row9_col0" class="data row9 col0" >penalty</td>
#       <td id="T_8c489_row9_col1" class="data row9 col1" >l2</td>
#       <td id="T_8c489_row9_col2" class="data row9 col2" >l2</td>
#       <td id="T_8c489_row9_col3" class="data row9 col3" >l1</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8c489_row10_col0" class="data row10 col0" >random_state</td>
#       <td id="T_8c489_row10_col1" class="data row10 col1" >None</td>
#       <td id="T_8c489_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_8c489_row10_col3" class="data row10 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_8c489_row11_col0" class="data row11 col0" >solver</td>
#       <td id="T_8c489_row11_col1" class="data row11 col1" >lbfgs</td>
#       <td id="T_8c489_row11_col2" class="data row11 col2" >lbfgs</td>
#       <td id="T_8c489_row11_col3" class="data row11 col3" >liblinear</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_8c489_row12_col0" class="data row12 col0" >tol</td>
#       <td id="T_8c489_row12_col1" class="data row12 col1" >0.000100</td>
#       <td id="T_8c489_row12_col2" class="data row12 col2" >0.000100</td>
#       <td id="T_8c489_row12_col3" class="data row12 col3" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_8c489_row13_col0" class="data row13 col0" >verbose</td>
#       <td id="T_8c489_row13_col1" class="data row13 col1" >0</td>
#       <td id="T_8c489_row13_col2" class="data row13 col2" >0</td>
#       <td id="T_8c489_row13_col3" class="data row13 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8c489_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_8c489_row14_col0" class="data row14 col0" >warm_start</td>
#       <td id="T_8c489_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_8c489_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_8c489_row14_col3" class="data row14 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

#Example code to fit model:
model = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0,
    max_depth=1, random_state=0).fit(preprocessor(X_train), y_train_labels)
model.score(preprocessor(X_train), y_train_labels)

# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=preprocessor(X_test).shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

#-- Generate predicted values (a list of predicted labels "real" or "fake")
prediction_labels = model.predict(preprocessor(X_test))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 6
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:1656
